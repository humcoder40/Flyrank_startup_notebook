# %% [markdown]
# <a href="https://colab.research.google.com/github/humcoder40/Flyrank_startup_notebook/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/humcoder40/Flyrank_startup_notebook/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane 2 — Refresh / Content Opportunity Scoring
#
# Why: Building a machine learning model to capture complex relationships across impressions, CTR decay, and position shifts is much more effective than relying on rigid rules (like page age alone) to prioritize true candidates for a content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The Decision: Which declining or stale pages should be prioritized for an editorial review first?
#
# Unit of Analysis: A single pseudonymized content item (content_hash_id).
#
# The Action: An editor spends manual work hours reviewing, expanding, or rewriting the top-ranked candidate pages.
#
# Cost of a Wrong Call: Wasted editorial time on pages that won't recover, while high-value decaying pages are ignored and continue to lose organic traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset directly from your raw GitHub file
df = pd.read_csv("https://raw.githubusercontent.com/humcoder40/Flyrank_startup_notebook/main/data/raw/content_refresh_anonymized.csv")

total_pages = len(df)
declining_pages = (df["trend_direction"] == "down").sum()
stale_high_imp = ((df["content_age_days"] >= 180) & (df["impressions_90d"] >= 500)).sum()

print(f"Evidence for Lane 2:")
print(f"1. Total eligible pages: {total_pages}")
print(f"2. Pages showing a downward trend: {declining_pages}")
print(f"3. Stale pages (180+ days old) with high demand (500+ impressions): {stale_high_imp}")
# Out:
# Evidence for Lane 2:
# 1. Total eligible pages: 30000
# 2. Pages showing a downward trend: 16262
# 3. Stale pages (180+ days old) with high demand (500+ impressions): 9929

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I CAN claim: A learned classification model prioritizes decaying pages with search demand significantly better than fixed baseline rules, improving the Precision@K for the review queue.
#
# What I CANNOT claim: Updating a flagged page guarantees a traffic recovery, or that I have reverse-engineered Google's search algorithms. This model provides decision support, not causal guarantees.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
